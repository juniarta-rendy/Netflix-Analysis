# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r'G:\Dataset\Netflix\netflix.csv', encoding = 'utf-8')

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.shape
# Out:
# (7789, 11)

# %% [markdown]
# ##### Remove Duplicates

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (7787, 11)

# %% [markdown]
# ##### Showing Null Values

# %%
df.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df[df['Title'].isin(['House of Cards'])]
# Out:
#      Show_Id Category           Title  \
# 2832   s2833  TV Show  House of Cards
#
#                                                Director  \
# 2832  Robin Wright, David Fincher, Gerald McRaney, J...
#
#                                                    Cast        Country  \
# 2832  Kevin Spacey, Robin Wright, Kate Mara, Corey S...  United States
#
#           Release_Date Rating   Duration                     Type  \
# 2832  November 2, 2018  TV-MA  6 Seasons  TV Dramas, TV Thrillers
#
#                                             Description
# 2832  A ruthless politician will stop at nothing to ...

# %% [markdown]
# ##### Top 5 Years Highest Release TV Shows & Movies

# %%
df['Release_Date'] = df['Release_Date'].str.strip()

# %%
df['Date_N'] = pd.to_datetime(df['Release_Date'])

# %%
top_10 = df['Date_N'].dt.year.value_counts().sort_values(ascending=False).head(5)

# %%
top_10
# Out:
# Date_N
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# Name: count, dtype: int64

# %%
plt.bar(top_10.index,top_10.values)
plt.xlabel('Release Year')
plt.ylabel('Number of TV Shows & Movies')
plt.title('Top 10 Highest Release Years')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Movies & TV Shows in Dataset

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
sns.countplot(x='Category', data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %% [markdown]
# ##### Show Movie that were Releases in 2020

# %%
df['Year'] = df['Date_N'].dt.year

# %%
#filtering
movie_2020 = df[(df['Category'] == 'Movie') & (df['Year'] == 2020)]

# %%
len(movie_2020)
# Out:
# 1312

# %% [markdown]
# ##### TV Shows that releases in India Only

# %%
#filtering
india_show = df[(df['Country'] == 'India') & (df['Category'] == 'TV Show')]

# %%
india_show.head()
# Out:
#     Show_Id Category                         Title     Director  \
# 86      s87  TV Show  21 Sarfarosh: Saragarhi 1897          NaN
# 132    s133  TV Show                     7 (Seven)  Nizar Shafi
# 340    s341  TV Show                  Agent Raghav          NaN
# 364    s365  TV Show                  Akbar Birbal          NaN
# 533    s534  TV Show           Anjaan: Rural Myths          NaN
#
#                                                   Cast Country  \
# 86                  Luke Kenny, Mohit Raina, Mukul Dev   India
# 132  Rahman, Havish, Regina Cassandra, Nandita Swet...   India
# 340  Sharad Kelkar, Aahana Kumra, Mahesh Manjrekar,...   India
# 364          Kiku Sharda, Vishal Kotian, Delnaaz Irani   India
# 533                                                NaN   India
#
#           Release_Date Rating  Duration  \
# 86    December 1, 2018  TV-14  1 Season
# 132      July 30, 2019  TV-14  1 Season
# 340     April 15, 2017  TV-14  1 Season
# ...

# %% [markdown]
# ##### Top 10 Director with Highest number of TV Shows & Movies to Netflix

# %%
df['Director'].value_counts().sort_values(ascending=False).head(10)
# Out:
# Director
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Youssef Chahine           12
# Martin Scorsese           12
# Steven Spielberg          10
# David Dhawan               9
# Shannon Hartman            8
# Name: count, dtype: int64

# %% [markdown]
# ##### All Records where "Category = Movie, Type = Comedies or Country = UK"

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
records = df[(df['Category'] == 'Movie') & (df['Type'] == 'Comedies') | (df['Country'] == 'United Kingdom')]

# %%
records
# Out:
#      Show_Id Category                   Title          Director  \
# 19       s20    Movie                     '89               NaN
# 33       s34    Movie            #realityhigh  Fernando Lebrija
# 58       s59  TV Show             100% Hotter               NaN
# 72       s73    Movie                17 Again       Burr Steers
# 82       s83    Movie     2036 Origin Unknown     Hasraf Dulull
# ...      ...      ...                     ...               ...
# 7670   s7669  TV Show  World War II in Colour               NaN
# 7671   s7670  TV Show  World's Busiest Cities               NaN
# 7688   s7687    Movie  XV: Beyond the Tryline  Pierre Deschamps
# 7725   s7724    Movie            You Can Tutu       James Brown
# 7740   s7739  TV Show         Young Wallander               NaN
#
#                                                    Cast         Country  \
# 19                   Lee Dixon, Ian Wright, Paul Merson  United Kingdom
# ...

# %% [markdown]
# ##### Movies where Tom Cruise were Cast

# %%
new_df = df.dropna()

# %%
tom = new_df[new_df['Cast'].str.contains('Tom Cruise')]

# %%
tom
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#          Release_Date Rating Duration                        Type  \
# 3860  January 1, 2020      R  189 min  Dramas, Independent Movies
# 5071     July 1, 2019      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# ##### Difference between Ratings defined by Netflix

# %%
df.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
df['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
df['Rating'].nunique()
# Out:
# 14

# %% [markdown]
# ##### Movies with TV-14' rating in Canada

# %%
canada_tv14 = df[(df['Rating'] == 'TV-14') & (df['Country'] == 'Canada') ]

# %%
canada_tv14
# Out:
#      Show_Id Category                                        Title  \
# 30       s31    Movie                             #cats_the_mewvie
# 34       s35    Movie                                        #Roxy
# 608     s609    Movie                               At First Light
# 791     s792  TV Show                           Beauty & the Beast
# 862     s863  TV Show                                      Between
# 994     s995  TV Show                                   Blown Away
# 1047   s1048  TV Show        Border Security: America's Front Line
# 1506   s1507    Movie                   Counterfeiting in Suburbia
# 1687   s1688  TV Show                         Degrassi: Next Class
# 2678   s2679  TV Show                                    Heartland
# 3713   s3714    Movie                            Long Time Running
# 3730   s3731  TV Show                                    Lost Girl
# 3956   s3957    Movie  Martin Matte: La vie, la mort...eh la la..!
# ...

# %%
len(canada_tv14)
# Out:
# 23

# %% [markdown]
# ##### Movies with 'R' rating after 2018

# %%
r_2018 = df[(df['Rating'] == 'R') & (df['Year'] > 2018)]

# %%
r_2018
# Out:
#      Show_Id Category               Title                       Director  \
# 7         s8    Movie                 187                 Kevin Reynolds
# 14       s15    Movie                3022                     John Suits
# 65       s66    Movie             13 Sins                   Daniel Stamm
# 68       s69    Movie           14 Blades                     Daniel Lee
# 83       s84    Movie  20th Century Women                     Mike Mills
# ...      ...      ...                 ...                            ...
# 7659   s7658    Movie           Woodshock  Kate Mulleavy, Laura Mulleavy
# 7712   s7711    Movie       Yes, God, Yes                    Karen Maine
# 7738   s7737    Movie         Young Adult                  Jason Reitman
# 7776   s7775    Movie              Zodiac                  David Fincher
# 7780   s7779    Movie          Zombieland                Ruben Fleischer
#
#                                                    Cast  \
# ...

# %% [markdown]
# ##### Maximum & Minimum duration of a Movie/Show on Netflix

# %%
df[['Minutes','Unit']] = df['Duration'].str.split(' ', expand=True)

# %%
max_duration = max(df['Minutes'].astype(int))
min_duration = min(df['Minutes'].astype(int))

# %%
print(f'Max Duration: {max_duration} Minutes')
print(f'Min Duration: {min_duration} Minute')
# Out:
# Max Duration: 312 Minutes
# Min Duration: 1 Minute

# %% [markdown]
# ##### Individual Country with Highest No. of TV Shows

# %%
data_tvshow = df[df['Category'] == 'TV Show']

# %%
data_tvshow.Country.value_counts()
# Out:
# Country
# United States                                                705
# United Kingdom                                               204
# Japan                                                        157
# South Korea                                                  147
# India                                                         71
#                                                             ...
# Canada, United States, United Kingdom, France, Luxembourg      1
# United States, Italy                                           1
# Chile, Italy                                                   1
# Canada, United Kingdom                                         1
# United States, France, South Korea, Indonesia                  1
# Name: count, Length: 183, dtype: int64

# %%
data_tvshow.Country.value_counts().head(1)
# Out:
# Country
# United States    705
# Name: count, dtype: int64

# %% [markdown]
# ##### How to sort the dataset by Year

# %%
df.sort_values('Year', ascending=False)
# Out:
#      Show_Id Category                         Title                 Director  \
# 5564   s5564    Movie               Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie                     Surf's Up  Ash Brannon, Chris Buck
# 980     s981  TV Show                  Bling Empire                      NaN
# 5955   s5955    Movie              Taare Zameen Par               Aamir Khan
# 366     s367    Movie                     Al acecho      Francisco D'Eufemia
# ...      ...      ...                           ...                      ...
# 3374   s3375  TV Show                      Kikoriki                      NaN
# 3492   s3493  TV Show           La Familia P. Luche                      NaN
# 3946   s3947  TV Show                         Maron                      NaN
# 5138   s5138  TV Show                  Red vs. Blue                      NaN
# 6066   s6066  TV Show  The Adventures of Figaro Pho                      NaN
#
# ...

# %% [markdown]
# ##### All instances where: Category = Movie & Type = Dramas or Category = 'TV Show & Type = Kids' TV

# %%
df[(df['Category'] == 'Movie') & (df['Type'].str.contains('Dramas'))].head(5)
# Out:
#    Show_Id Category   Title           Director  \
# 1       s2    Movie   07:19  Jorge Michel Grau
# 4       s5    Movie      21     Robert Luketic
# 7       s8    Movie     187     Kevin Reynolds
# 10     s11    Movie    1922       Zak Hilditch
# 15     s16    Movie  Oct-01     Kunle Afolayan
#
#                                                  Cast        Country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria
#
#          Release_Date Rating Duration  \
# 1   December 23, 2016  TV-MA   93 min
# 4     January 1, 2020  PG-13  123 min
# 7    November 1, 2019      R  119 min
# 10   October 20, 2017  TV-MA  103 min
# 15  September 1, 2019  TV-14  149 min
#
# ...

# %%
df[(df['Category'] == 'TV Show') & (df['Type'].str.contains("Kids' TV"))].head(5)
# Out:
#     Show_Id Category                           Title     Director  \
# 108    s109  TV Show        3Below: Tales of Arcadia          NaN
# 111    s112  TV Show                         44 Cats          NaN
# 225    s226  TV Show  A Series of Unfortunate Events          NaN
# 276    s277  TV Show                    Abby Hatcher  Kyran Kelly
# 364    s365  TV Show                    Akbar Birbal          NaN
#
#                                                   Cast                Country  \
# 108  Tatiana Maslany, Diego Luna, Nick Offerman, Ni...          United States
# 111  Sarah Natochenny, Suzy Myers, Simona Berman, E...                  Italy
# 225  Neil Patrick Harris, Patrick Warburton, Malina...          United States
# 276  Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...  United States, Canada
# 364          Kiku Sharda, Vishal Kotian, Delnaaz Irani                  India
#
#         Release_Date Rating   Duration  \
# 108    July 12, 2019  TV-Y7  2 Seasons
# ...

# %%
df[(df['Category'] == 'Movie') & 
   (df['Type'].str.contains('Dramas')) | 
   (df['Category'] == 'TV Show') & 
   (df['Type'].str.contains("Kids' TV"))].head(5)
# Out:
#    Show_Id Category   Title           Director  \
# 1       s2    Movie   07:19  Jorge Michel Grau
# 4       s5    Movie      21     Robert Luketic
# 7       s8    Movie     187     Kevin Reynolds
# 10     s11    Movie    1922       Zak Hilditch
# 15     s16    Movie  Oct-01     Kunle Afolayan
#
#                                                  Cast        Country  \
# 1   Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 4   Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7   Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
# 10  Thomas Jane, Molly Parker, Dylan Schmid, Kaitl...  United States
# 15  Sadiq Daba, David Bailie, Kayode Olaiya, Kehin...        Nigeria
#
#          Release_Date Rating Duration  \
# 1   December 23, 2016  TV-MA   93 min
# 4     January 1, 2020  PG-13  123 min
# 7    November 1, 2019      R  119 min
# 10   October 20, 2017  TV-MA  103 min
# 15  September 1, 2019  TV-14  149 min
#
# ...
